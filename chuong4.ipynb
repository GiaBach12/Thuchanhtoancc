# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaBach12/Thuchanhtoancc/blob/main/chuong4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Thực hành 1: Chia khoảng dữ liệu **

# %%
import numpy as np
mienchia = np.linspace(0, 2, 11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %% [markdown]
# #**Thực hành 2: Vẽ các đồ thị **

# %%
import numpy as np
import matplotlib.pyplot as plt
fs = [1, 2, 4]
all_time = np.linspace(0, 2, 200)
t = all_time[:100] 
for f in fs: 
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label='{} Hz'.format(f))
plt.legend() 
import os
plt.savefig('basics_python.pdf')
plt.show()

# %% [markdown]
# **2 đoạn mã với điểm khác biệt chính là việc sử dụng vòng lặp for để vẽ: **

# %% [markdown]
# #**Giải pháp hướng đối tượng: Vẽ các hình như là các đối tượng “con” của plt: **

# %%
fig, ax = plt.subplots() 
for f in fs:
   y = np.sin(2 * np.pi * f * t) 
   ax.plot(t, y, label='{} Hz'.format(f))

# %% [markdown]
# #**Giải pháp hướng máy trạng thái: Vẽ các hình trực tiếp lên trên đối tượng plt: **

# %%
for f in fs: 
  y = np.sin(2 * np.pi * f * t) 
  plt.plot(t, y, label='{} Hz'.format(f))

# %% [markdown]
# #**Thực hành 3: Xây dựng chương trình hướng đối tượng **

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
fig,ax=plt.subplots()
for f in fs:
  y=np.sin(2*np.pi*f*t)
  ax.plot(t,y,label='()Hz'.format(f))
plt.legend()
import os
plt.savefig('basics_python.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='()Hz'.format(f))
plt.legend()
import os
plt.savefig('basics_python.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #**Thực hành 4: Minh họa cơ bản về hàm lambda**

# %%
def f(x):return x**2
print(f(8))

g=lambda x:x**2
print(g(8))
# Out:
# 64
# 64

# %% [markdown]
# #**Thực hành 5: Tính thuế theo từng khu vực**

# %%
def thue(phan_tram): return lambda x: x * phan_tram
hcm = thue(0.012)
hn = thue(0.01) 
hcm(1000000)
# Out:
# 12000.0

# %%
def thue(phan_tram): return lambda x: x * phan_tram
hcm = thue(0.012)
hn = thue(0.01) 
hn(1000000)
# Out:
# 10000.0

# %% [markdown]
# #**Thực hành 6: Biểu diễn cài đặt phương pháp hình thang với hàm lambda **

# %%
hinhthang = lambda f, a, b: (b-a)*(f(a)+f(b))/2 
from math import exp 
hinhthang(exp,0, 1) 
1.8591409142295225
def hai_x(x): return 2*x 
hinhthang(hai_x, 1, 2)
# Out:
# 3.0

# %% [markdown]
# #**Thực hành 7: Xây dựng hàm tính tích phân cho e^x bằng phương pháp hình thang **

# %%
def traprule(ham, trai, phai):    
 return (phai-trai)*(ham(trai) + ham(phai))/2 
import math 
S = "Bieu thuc can tinh tich phan la e^x:" 
print(S + '[a,b]')
A = float(input('Nhap a : ')) 
B = float(input('Nhap b : ')) 
Y = traprule(math.exp, A, B) 
print(S + "[%.1E,%.1E] : " % (A, B)) 
print('Gia tri xap xi : %.15E' % Y) 
E = math.exp(B) - math.exp(A) 
print(' Gia tri chinh xac : %.15E' % E)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-1b4834d755d7> in <module>()
#       3 import math
#       4 S = "Bieu thuc can tinh tich phan la e^x:"
# ----> 5 print(S + '[a,b]')
#       6 A = float(input('Nhap a : '))
#       7 B = float(input('Nhap b : '))
#
# TypeError: 'float' object is not callable
